# %%
import pandas as pd 
df = pd.read_csv('/Users/d.mkhlnk/ОКТ/Граф агентов (агентный бустинг)/results/metrics_comparison.csv')

df
# Out:
#                                    Метод оценки  \
# 0               SVM (baseline) (из статьи) [11]
# 1    Gemini 3.1 Pro (baseline) (из статьи) [11]
# 2    Врачи-нейрохирурги (HITL) (из статьи) [11]
# 3  Math Agent (cascade) + Gemini 3.1 Flash-Lite
# 4                             Math Agent (only)
#
#    Чувствительность (Sensitivity), %  Специфичность (Specificity), %  \
# 0                               83.0                            85.0
# 1                               86.0                            93.0
# 2                               98.0                            90.0
# 3                               90.5                            93.2
# 4                               90.5                            88.6
#
#    Общая точность (Global Accuracy), %
# 0                                 84.0
# 1                                 90.0
# 2                                 94.0
# 3                                 91.9
# 4                                 89.5
